# %%
import pandas as pd
# Load the CSV file
file_path = "/Users/manoharshasappa/Desktop/Files/Github_Files/notable_ai_models.csv"
df = pd.read_csv(file_path)

# %%
# Display basic info about the DataFrame
print("DataFrame Info:")
print(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   System                              867 non-null    object
#  1   Domain                              867 non-null    object
#  2   Organization                        853 non-null    object
#  3   Organization categorization         853 non-null    object
#  4   Country (from Organization)         853 non-null    object
#  5   Authors                             836 non-null    object
#  6   Publication date                    867 non-null    object
#  7   Reference                           858 non-null    object
#  8   Link                                865 non-null    object
#  9   Citations                           758 non-null    float64
#  10  Notability criteria                 867 non-null    object
# ...

# %%
# Display first few rows for reference
print("\nFirst 5 Rows of the DataFrame:")
print(df.head(5))
# Out:
# First 5 Rows of the DataFrame:
#                System    Domain     Organization Organization categorization  \
# 0         Qwen2.5-72B  Language          Alibaba                    Industry
# 1  Table Tennis Agent  Robotics  Google DeepMind                    Industry
# 2          AFM-server  Language            Apple                    Industry
# 3       AFM-on-device  Language            Apple                    Industry
# 4     Mistral Large 2  Language       Mistral AI                    Industry
#
#   Country (from Organization)  \
# 0                       China
# 1               Multinational
# 2    United States of America
# 3    United States of America
# 4                      France
#
#                                              Authors Publication date  \
# 0                                                NaN       2024-09-19
# 1  David B. D'Ambrosio, Saminda Abeyruwan, Laura ...       2024-08-07
# 2  Andy Narayanan, Aonan Zhang, Bowen Zhang, Chen...       2024-07-29
# ...

# %%
# Check for null values
print("\nNull Values in Each Column:")
print(df.isnull().sum())
# Out:
# Null Values in Each Column:
# System                                  0
# Domain                                  0
# Organization                           14
# Organization categorization            14
# Country (from Organization)            14
# Authors                                31
# Publication date                        0
# Reference                               9
# Link                                    2
# Citations                             109
# Notability criteria                     0
# Notability criteria notes             427
# Parameters                            287
# Parameters notes                      365
# Training compute (FLOP)               445
# Training compute notes                436
# Training dataset                      430
# Training dataset notes                569
# Training dataset size (datapoints)    438
# Dataset size notes                    429
# Epochs                                657
# Training time (hours)                 676
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Year'] = pd.to_datetime(df['Publication date'], errors='coerce').dt.year

#Number of models per year
models_per_year = df['Year'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.bar(models_per_year.index, models_per_year.values, color='blue')
plt.xlabel('Year')
plt.ylabel('Number of Models')
plt.title('Number of AI Models Released Per Year')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Total number of models in dataset
unique_models = df['System'].dropna().unique()
num_models = len(unique_models)

# Print the number of unique AI models and list them
print(f"Total Unique AI Models: {num_models}")
print("List of AI Models:")
for model in unique_models:
    print(model)
# Out:
# Total Unique AI Models: 867
# List of AI Models:
# Qwen2.5-72B
# Table Tennis Agent
# AFM-server
# AFM-on-device
# Mistral Large 2
# Llama 3.1-405B
# ESM3 (98B)
# Claude 3.5 Sonnet
# GLM-4 (0520)
# DeepSeek-Coder-V2 236B
# Nemotron-4 340B
# OpenVLA
# Qwen2-72B
# GPT-4o
# Llama 3-70B
# ReALM
# MM1-30B
# Inflection-2.5
# Claude 3 Opus
# MegaScale (Production)
# Sora
# Gemini 1.5 Pro
# Aya
# Qwen1.5 72B
# Qwen-VL-Max
# AlphaGeometry
# CoRe
# Gemini Nano-2
# Gemini Nano-1
# FunSearch
# CogAgent
# Mixtral 8x7B
# SeamlessM4T
# Llama Guard
# Gemini 1.0 Ultra
# Gemini 1.0 Pro
# Mamba-24M (SC09)
# Qwen-72B
# PPLX-70B-Online
# Inflection-2
# Claude 2.1
# Nemotron-3-8B
# Qwen-Audio-Chat
# GraphCast
# Volcano 13B
# SPHINX (Llama 2 13B)
# MultiBand Diffusion
# OmniVec
# mPLUG-Owl2
# GPT-4 Turbo
# CogVLM-17B
# LLaVA 1.5
# RT-Trajectory
# BLUUMI
# Yi-34B
# Cohere Embed
# Skywork-13B
# ChatGLM3-6B
# DiT-XL/2 + CADS
# CODEFUSION (Python)
# QMoE: compressed 1T model
# DALL·E 3
# ERNIE 4.0
# RT-2-X
# ...

# %%
# Extract years from the 'Publication date' column
df['Year'] = pd.to_datetime(df['Publication date'], errors='coerce').dt.year

# Number of models per organization
models_per_org = df['Organization'].value_counts().head(10) 
plt.figure(figsize=(12, 6))
plt.barh(models_per_org.index, models_per_org.values, color='purple')
plt.xlabel('Number of Models')
plt.ylabel('Organization')
plt.title('Top 10 Organizations by AI Model Count')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Graph: Distribution of models by domain
models_by_domain = df['Domain'].value_counts()
plt.figure(figsize=(12, 6))
plt.bar(models_by_domain.index, models_by_domain.values, color='orange')
plt.xlabel('Domain')
plt.ylabel('Number of Models')
plt.title('Distribution of AI Models by Domain')
plt.xticks(rotation=90, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# AI Model Growth Over the Years
models_per_year = df['Year'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.plot(models_per_year.index, models_per_year.values, marker='o', linestyle='-', color='blue')
plt.xlabel('Year')
plt.ylabel('Number of Models')
plt.title('AI Model Growth Over the Years')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Model accessibility distribution
model_accessibility = df['Model accessibility'].value_counts()
plt.figure(figsize=(12, 6))
plt.pie(model_accessibility, labels=model_accessibility.index, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'orange', 'red', 'purple'])
plt.title('AI Model Accessibility Distribution')
plt.show()
